# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import seaborn as sns
import plotly
#from nba_api.static import teams

# %% [markdown]
# # Data Source

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_stats.html' # URL for league stats

file = '/Users/benjaminxiao/Documents/swd_challenges/jan_19_sub/nba_league_data.csv' # on mini

# %%
df = pd.read_csv(file)

# %%
test_df = df.copy()

# %%
df.head(n=5) # Check dataframe was loaded properly
# Out:
#    Rk   Season   Lg   Age   Ht     Wt     G     MP    FG   FGA  ...      PTS  \
# 0   1  2018-19  NBA  26.4  6-7  218.0   637  241.7  40.8  88.7  ...    110.3
# 1   2  2017-18  NBA  26.4  6-7  219.0  1230  241.4  39.6  86.1  ...    106.3
# 2   3  2016-17  NBA  26.6  6-7  220.0  1230  241.6  39.0  85.4  ...    105.6
# 3   4  2015-16  NBA  26.7  6-7  221.0  1230  241.8  38.2  84.6  ...    102.7
# 4   5  2014-15  NBA  26.7  6-7  222.0  1230  242.0  37.5  83.6  ...    100.0
#
#      FG%    3P%    FT%  Pace   eFG%  TOV%  ORB%  FT/FGA   ORtg
# 0  0.460  0.354  0.764  99.5  0.522  12.4  23.0   0.200  110.0
# 1  0.460  0.362  0.767  97.3  0.521  13.0  22.3   0.193  108.6
# 2  0.457  0.358  0.772  96.4  0.514  12.7  23.3   0.209  108.8
# 3  0.452  0.354  0.757  95.8  0.502  13.2  23.8   0.209  106.4
# 4  0.449  0.350  0.750  93.9  0.496  13.3  25.1   0.205  105.6
#
# [5 rows x 32 columns]

# %%
print(list(df)) # Check all columns
# Out:
# ['Rk', 'Season', 'Lg', 'Age', 'Ht', 'Wt', 'G', 'MP', 'FG', 'FGA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '3P%', 'FT%', 'Pace', 'eFG%', 'TOV%', 'ORB%', 'FT/FGA', 'ORtg']

# %%
print(df.dtypes)
# Out:
# Rk          int64
# Season     object
# Lg         object
# Age       float64
# Ht         object
# Wt        float64
# G           int64
# MP        float64
# FG        float64
# FGA       float64
# 3P        float64
# 3PA       float64
# FT        float64
# FTA       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# FG%       float64
# 3P%       float64
# FT%       float64
# Pace      float64
# eFG%      float64
# TOV%      float64
# ORB%      float64
# FT/FGA    float64
# ORtg      float64
# dtype: object

# %%
df['Season'][0][:4]
# Out:
# '2018'

# %%
# NBA after Jordan's last championship, 97-98 season
# Filter seasons to after this
def filter_year(start, end, df, i):
    try:
        year = int(df['Season'][i][:4])
        if year >= start:
            print('True')
            #return True
    except:
        return False

# %%
filter_year(1980, 2019, df)
# Out:
# True

# %%
df = df[:40]

# %%
df.tail(n=5)
# Out:
#     Rk   Season   Lg   Age   Ht     Wt    G     MP    FG   FGA  ...      PTS  \
# 35  36  1983-84  NBA  26.4  6-7  206.0  943  242.0  43.5  88.4  ...    110.1
# 36  37  1982-83  NBA  26.1  6-7  205.0  943  241.3  43.5  89.7  ...    108.5
# 37  38  1981-82  NBA  26.2  6-7  205.0  943  241.6  43.3  88.2  ...    108.6
# 38  39  1980-81  NBA  26.2  6-7  205.0  943  241.4  43.0  88.4  ...    108.1
# 39  40  1979-80  NBA  26.4  6-6  204.0  902  241.8  43.6  90.6  ...    109.3
#
#       FG%    3P%    FT%   Pace   eFG%  TOV%  ORB%  FT/FGA   ORtg
# 35  0.492  0.250  0.760  101.4  0.495  15.0  33.0   0.255  107.6
# 36  0.485  0.238  0.740  103.1  0.488  15.8  33.4   0.233  104.7
# 37  0.491  0.262  0.746  100.9  0.495  15.0  33.0   0.241  106.9
# 38  0.486  0.245  0.751  101.8  0.489  15.6  33.5   0.245  105.5
# 39  0.481  0.280  0.764  103.1  0.486  15.5  33.5   0.235  105.3
#
# [5 rows x 32 columns]

# %%
df
# Out:
#     Rk   Season   Lg   Age   Ht     Wt     G     MP    FG   FGA  ...      PTS  \
# 0    1  2018-19  NBA  26.4  6-7  218.0   637  241.7  40.8  88.7  ...    110.3
# 1    2  2017-18  NBA  26.4  6-7  219.0  1230  241.4  39.6  86.1  ...    106.3
# 2    3  2016-17  NBA  26.6  6-7  220.0  1230  241.6  39.0  85.4  ...    105.6
# 3    4  2015-16  NBA  26.7  6-7  221.0  1230  241.8  38.2  84.6  ...    102.7
# 4    5  2014-15  NBA  26.7  6-7  222.0  1230  242.0  37.5  83.6  ...    100.0
# 5    6  2013-14  NBA  26.5  6-7  223.0  1230  242.0  37.7  83.0  ...    101.0
# 6    7  2012-13  NBA  26.7  6-7  223.0  1229  241.9  37.1  82.0  ...     98.1
# 7    8  2011-12  NBA  26.6  6-7  223.0   990  241.9  36.5  81.4  ...     96.3
# 8    9  2010-11  NBA  26.6  6-7  223.0  1230  241.9  37.2  81.2  ...     99.6
# 9   10  2009-10  NBA  26.6  6-7  222.0  1230  241.7  37.7  81.7  ...    100.4
# 10  11  2008-09  NBA  26.6  6-7  221.0  1230  241.7  37.1  80.9  ...    100.0
# ...
